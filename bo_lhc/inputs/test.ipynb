# %%
from input_gas_jet_height import GasJetHeight

gas_jet_height = GasJetHeight(bounds=(0, 4))
print(gas_jet_height)
print("Position: ", gas_jet_height.get_position())

gas_jet_height.set_bounds((1, 3))
print(gas_jet_height)
# Out:
# <GasJetHeight(name='gas_jet_height', bounds=(0, 4), unit=um)>
# Position:  None
# <GasJetHeight(name='gas_jet_height', bounds=(1, 3), unit=um)>

# %%
gas_jet_height?
# Out:
# Type:           GasJetHeight
# String form:    <GasJetHeight(name='gas_jet_height', bounds=(1, 3), unit=um)>
# File:           c:\users\appli\documents\github\bo_laplace\inputs\input_gas_jet_height.py
# Docstring:      Test
# Init docstring: bounds defines the boundaries of the system
